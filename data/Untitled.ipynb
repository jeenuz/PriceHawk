# %%
import pandas as pd
from pdfunc import *

# %%
df=pd.read_csv("prices_2026-04-03T13-10-22+00-00.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   object
#  1   price         1000 non-null   float64
#  2   currency      1000 non-null   object
#  3   availability  1000 non-null   object
#  4   rating        1000 non-null   object
#  5   url           1000 non-null   object
#  6   retailer      1000 non-null   object
#  7   scraped_at    1000 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 62.6+ KB

# %%
sample(df)
# Out:
# title
#  Animal Farm
#
# price
#  57.22
#
# currency
#  GBP
#
# availability
#  nan
#
# rating
#  3/5
#
# url
#  http://books.toscrape.com/catalogue/animal-farm_313/index.html
#
# retailer
#  books.toscrape.com
#
# scraped_at
#  2026-04-03T11:07:20.357442+00:00
